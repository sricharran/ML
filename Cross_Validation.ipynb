# %% [markdown]
# import necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# importing models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
data = pd.read_csv("Iris.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 6)

# %%
le = LabelEncoder()

data['Species'] = le.fit_transform(data['Species'])
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
data['Species'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: Species, dtype: int64

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
X = data.drop(['Species'],axis=1)
Y = data['Species']

# %%
models = [LogisticRegression(max_iter = 1000),SVC(kernel='linear'),KNeighborsClassifier(),RandomForestClassifier()]

# %% [markdown]
# **CV**

# %%
def CV_models():
  for model in models:
    cv_score = cross_val_score(model,X,Y,cv=5)

    mean_accuracy = sum(cv_score)/len(cv_score)
    mean_accuracy = mean_accuracy*100
    mean_accuracy = round(mean_accuracy,2)

    print("Cross Validation score of ",model,": ",cv_score)
    print("mean accuracy : ",mean_accuracy)
    print("--------------------------------------------------------------------------")

# %%
CV_models()
# Out:
# Cross Validation score of  LogisticRegression(max_iter=1000) :  [0.7 1.  1.  1.  0.7]
# mean accuracy :  88.0
# --------------------------------------------------------------------------
# Cross Validation score of  SVC(kernel='linear') :  [0.66666667 1.         1.         1.         0.7       ]
# mean accuracy :  87.33
# --------------------------------------------------------------------------
# Cross Validation score of  KNeighborsClassifier() :  [0.66666667 1.         1.         1.         0.7       ]
# mean accuracy :  87.33
# --------------------------------------------------------------------------
# Cross Validation score of  RandomForestClassifier() :  [0.96666667 1.         1.         1.         0.86666667]
# mean accuracy :  96.67
# --------------------------------------------------------------------------
